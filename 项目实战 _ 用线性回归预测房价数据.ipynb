# %% [markdown]
# # 项目：用线性回归预测房价数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析报告的目的是，基于已有的房屋销售价格，以及有关该房屋的属性，进行线性回归分析，从而利用得到的线性回归模型，能对以下未知售价的房屋根据属性进行价格预测：
#
# 面积为6500平方英尺，有4个卧室、2个厕所，总共2层，不位于主路，无客人房，带地下室，有热水器，没有空调，车位数为2，位于城市首选社区，简装修。

# %% [markdown]
# ## 简介

# %% [markdown]
# 数据集`house_price.csv`记录了超过五百栋房屋的交易价格，以及房屋的相关属性信息，包括房屋面积、卧室数、厕所数、楼层数、是否位于主路、是否有客房，等等。

# %% [markdown]
# `house_price.csv`每列的含义如下：
# - price：房屋出售价格
# - area：房屋面积，以平方英尺为单位
# - bedrooms：卧室数
# - bathrooms：厕所数
# - stories：楼层数
# - mainroad：是否位于主路
#    - yes  是
#    - no	  否
# - guestroom：是否有客房
#    - yes  是
#    - no	  否
# - basement：是否有地下室
#    - yes  是
#    - no	  否
# - hotwaterheating：是否有热水器
#    - yes  是
#    - no	  否
# - airconditioning：是否有空调
#    - yes  是
#    - no	  否
# - parking：车库容量，以车辆数量为单位
# - prefarea：是否位于城市首选社区
#    - yes  是
#    - no	  否
# - furnishingstatus：装修状态
#    - furnished       精装
#    - semi-furnished	 简装
#    - unfurnished     毛坯

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ori_house=pd.read_csv("house_price.csv")
ori_house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ## 评估清理数据

# %% [markdown]
# ### 数据整齐度

# %% [markdown]
# 数据无结构性问题

# %% [markdown]
# ### 数据干净度

# %%
cleaned_house=ori_house.copy()
cleaned_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# 无空缺值，可将一部分数据类型转换为分类数据

# %%
cleaned_house["mainroad"]=cleaned_house["mainroad"].astype("category")
cleaned_house["guestroom"]=cleaned_house["guestroom"].astype("category")
cleaned_house["basement"]=cleaned_house["basement"].astype("category")
cleaned_house["hotwaterheating"]=cleaned_house["hotwaterheating"].astype("category")
cleaned_house["airconditioning"]=cleaned_house["airconditioning"].astype("category")
cleaned_house["prefarea"]=cleaned_house["prefarea"].astype("category")
cleaned_house["furnishingstatus"]=cleaned_house["furnishingstatus"].astype("category")

# %%
cleaned_house["furnishingstatus"].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %% [markdown]
# 无不一致数据

# %%
cleaned_house.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# 无不符合实际的数据

# %% [markdown]
# ## 数据探索

# %%
sns.set_palette("autumn")

# %% [markdown]
# ### 房价分布

# %%
plt.rcParams["figure.figsize"]=[7,3.5]
plt.rcParams["figure.autolayout"]=True
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="price",ax=axes[0])
sns.boxplot(cleaned_house,y="price",ax=axes[1])
plt.show()

# %% [markdown]
# 呈右偏态分布，存在高价房极端值

# %% [markdown]
# ### 面积分布

# %%
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="area",ax=axes[0])
sns.boxplot(cleaned_house,y="area",ax=axes[1])
plt.show()

# %% [markdown]
# 类似房价

# %% [markdown]
# ### 房价与面积关系

# %%
sns.scatterplot(cleaned_house,x="area",y="price")
plt.show()

# %% [markdown]
# 去掉高房价大面积的极端值，初步目测呈一定的线性相关

# %% [markdown]
# ### 房价与卧室数关系

# %%
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="bedrooms",ax=axes[0])
sns.barplot(cleaned_house,x="bedrooms",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# 卧室数小于五个时，房价随卧室数增多而升高，但卧室数更多时，房价可能下降

# %% [markdown]
# ### 房价与卫生间数关系

# %%
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="bathrooms",ax=axes[0])
sns.barplot(cleaned_house,x="bathrooms",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# 房价随卫生间数增多而升高，但卫生间大多只有一个或两个

# %% [markdown]
# ### 房价与楼层数关系

# %%
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="stories",ax=axes[0])
sns.barplot(cleaned_house,x="stories",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# 房价随楼层数增多而升高，但楼层大多只有一到二层

# %% [markdown]
# ### 车库数与房价

# %%
figure,axes=plt.subplots(1,2)
sns.histplot(cleaned_house,x="parking",ax=axes[0])
sns.barplot(cleaned_house,x="parking",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 是否在主路与房价

# %%
sns.set_palette("Paired")
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["mainroad"].value_counts(),labels=cleaned_house["mainroad"].value_counts().index)
sns.barplot(cleaned_house,x="mainroad",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# 房子大多位于主路，且主路的房价也相对高

# %% [markdown]
# ### 是否有客房与房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["guestroom"].value_counts(),labels=cleaned_house["guestroom"].value_counts().index)
sns.barplot(cleaned_house,x="guestroom",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 是否有地下室与房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["basement"].value_counts(),labels=cleaned_house["basement"].value_counts().index)
sns.barplot(cleaned_house,x="basement",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 热水房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["hotwaterheating"].value_counts(),labels=cleaned_house["hotwaterheating"].value_counts().index)
sns.barplot(cleaned_house,x="hotwaterheating",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 空调房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["airconditioning"].value_counts(),labels=cleaned_house["airconditioning"].value_counts().index)
sns.barplot(cleaned_house,x="airconditioning",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 社区房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["prefarea"].value_counts(),labels=cleaned_house["prefarea"].value_counts().index)
sns.barplot(cleaned_house,x="prefarea",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ### 装修房价

# %%
figure,axes=plt.subplots(1,2)
axes[0].pie(cleaned_house["furnishingstatus"].value_counts(),labels=cleaned_house["furnishingstatus"].value_counts().index)
sns.barplot(cleaned_house,x="furnishingstatus",y="price",ax=axes[1])
plt.show()

# %% [markdown]
# ## 数据分析

# %%
import statsmodels.api as sm

# %%
lr_house_price=cleaned_house.copy()

# %%
lr_house_price
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
lr_house_price=pd.get_dummies(lr_house_price,drop_first=True,columns=["mainroad","guestroom","basement","hotwaterheating",
                                                       "airconditioning","prefarea","furnishingstatus"],dtype=int)
lr_house_price
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
y=lr_house_price["price"]
x=lr_house_price.drop("price",axis=1)

# %%
abs(x.corr())>=0.8
# Out:
#                                   area  bedrooms  bathrooms  stories  parking  \
# area                              True     False      False    False    False
# bedrooms                         False      True      False    False    False
# bathrooms                        False     False       True    False    False
# stories                          False     False      False     True    False
# parking                          False     False      False    False     True
# mainroad_yes                     False     False      False    False    False
# guestroom_yes                    False     False      False    False    False
# basement_yes                     False     False      False    False    False
# hotwaterheating_yes              False     False      False    False    False
# airconditioning_yes              False     False      False    False    False
# prefarea_yes                     False     False      False    False    False
# ...

# %% [markdown]
# 各变量间不存在强正相关

# %%
x=sm.add_constant(x)
x
# Out:
#      const  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0      1.0  7420         4          2        3        2             1
# 1      1.0  8960         4          4        4        3             1
# 2      1.0  9960         3          2        2        2             1
# 3      1.0  7500         4          2        2        3             1
# 4      1.0  7420         4          1        2        2             1
# ..     ...   ...       ...        ...      ...      ...           ...
# 540    1.0  3000         2          1        1        2             1
# 541    1.0  2400         3          1        1        0             0
# 542    1.0  3620         2          1        1        0             1
# 543    1.0  2910         3          1        1        0             0
# 544    1.0  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
model=sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     87.52
# Date:                Fri, 03 Oct 2025   Prob (F-statistic):          9.07e-123
# Time:                        15:41:23   Log-Likelihood:                -8331.5
# No. Observations:                 545   AIC:                         1.669e+04
# Df Residuals:                     531   BIC:                         1.675e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 将显著区间设为0.05，可以看到furnishingstatus_semi-furnished项和const项对房价影响不大

# %%
x=x.drop(["furnishingstatus_semi-furnished","bedrooms","const"],axis=1)
model=sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1088.
# Date:                Fri, 03 Oct 2025   Prob (F-statistic):                        0.00
# Time:                        15:50:54   Log-Likelihood:                         -8333.5
# No. Observations:                 545   AIC:                                  1.669e+04
# Df Residuals:                     534   BIC:                                  1.674e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# R方拟合度大大提高

# %%
price_to_predict=pd.DataFrame({"area":[6500],"bedrooms":[4],"bathrooms":[2],
                              "stories":[2],"mainroad":["no"],"guestroom":["no"],
                              "basement":["yes"],"hotwaterheating":["yes"],"airconditioning":["no"],
                              "parking":[2],"prefarea":["yes"],"furnishingstatus":["semi-furnished"]})
price_to_predict
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  6500         4          2        2       no        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0             yes              no        2      yes   semi-furnished

# %%
price_to_predict["mainroad"]=pd.Categorical(price_to_predict["mainroad"],categories=["yes","no"])
price_to_predict["guestroom"]=pd.Categorical(price_to_predict["guestroom"],categories=["yes","no"])
price_to_predict["basement"]=pd.Categorical(price_to_predict["basement"],categories=["yes","no"])
price_to_predict["hotwaterheating"]=pd.Categorical(price_to_predict["hotwaterheating"],categories=["yes","no"])
price_to_predict["airconditioning"]=pd.Categorical(price_to_predict["airconditioning"],categories=["yes","no"])
price_to_predict["prefarea"]=pd.Categorical(price_to_predict["prefarea"],categories=["yes","no"])
price_to_predict["furnishingstatus"]=pd.Categorical(price_to_predict["furnishingstatus"],categories=["furnished","semi-furnished","unfurnished"])

# %%
price_to_predict=pd.get_dummies(price_to_predict,drop_first=True,columns=["mainroad","guestroom","basement",
                                                                         "hotwaterheating","airconditioning",
                                                                         "prefarea","furnishingstatus"],dtype=int)
price_to_predict
# Out:
#    area  bedrooms  bathrooms  stories  parking  mainroad_no  guestroom_no  \
# 0  6500         4          2        2        2            1             1
#
#    basement_no  hotwaterheating_no  airconditioning_no  prefarea_no  \
# 0            0                   0                   1            0
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                1                             0

# %%
price_to_predict=price_to_predict.drop(["furnishingstatus_semi-furnished","bedrooms"],axis=1)

# %%
model.predict(price_to_predict)
# Out:
# 0    6.997695e+06
# dtype: float64
